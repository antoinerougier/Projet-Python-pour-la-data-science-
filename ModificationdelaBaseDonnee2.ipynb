# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("https://minio.lab.sspcloud.fr/arougier/donneefinances/Quelsques_cours_Actions_Bourse_Paris.csv", sep=";")
df
# Out:
#             ticker             label        date       open       high  \
# 0     FR0010340141               ADP       43832    176.800    178.100
# 1     FR0010340141               ADP       43833    176.000    176.000
# 2     FR0010340141               ADP       43836    173.300    173.300
# 3     FR0010340141               ADP       43837    172.700    173.100
# 4     FR0010340141               ADP       43838    171.800    173.600
# ...            ...               ...         ...        ...        ...
# 7340  XC0009694271  NASDAQ Composite  11/11/2022  11124.749  11352.429
# 7341  XC0009694271  NASDAQ Composite  14/11/2022  11233.904  11350.125
# 7342  XC0009694271  NASDAQ Composite  15/11/2022  11474.820  11492.616
# 7343  XC0009694271  NASDAQ Composite  16/11/2022  11260.095  11286.101
# 7344  XC0009694271  NASDAQ Composite  17/11/2022  11008.672  11198.838
#
#             low      close  volume currency
# 0       175.100    176.100   70483      EUR
# 1       173.200    173.700   45246      EUR
# 2       170.900    171.700   78258      EUR
# 3       171.900    172.100   36545      EUR
# 4       171.300    173.600   56082      EUR
# ...         ...        ...     ...      ...
# 7340  11069.829  11323.331       0      NaN
# 7341  11167.165  11196.220       0      NaN
# 7342  11241.152  11358.410       0      NaN
# 7343  11162.923  11183.659       0      NaN
# 7344  11006.213  11144.958       0      NaN
#
# [7345 rows x 9 columns]

# %%
#Il faut rajouter des statistiques descriptives sur le premier jeu de donnée

# %% [markdown]
# On remarque qu'il faut modifier cette base de données car certaines informations sont incomplètes, ou que les informations ne sont pas correctement mises pour notre analyse.
# Par exemple, les dates ne sont pas écrite de la même manière, et les devises sont absentes pour certaines actions. Il faut donc modifier cela. Les dates pour chaques actions vont du 2 Janvier 2022 jusqu'au 17 Novembre 2022. Nous devons donc modifer cela pour chaque actions
# Nous allons donc couper le tableau avec toutes les actions et effectuer cette modification sur chaque action puis remettre tous les tableaux ensemble

# %%
l = np.unique(df.label)
l

lst=[]
for x in l:
    lst.append(x)
    
print(lst)
len(lst)
# Out:
# ['ADP', 'AXA', 'BNP PARIBAS', 'CAC 40', 'DANONE', 'DAX', 'NASDAQ Composite', 'Nikkei 225', 'SANOFI', 'SOCIETE GENERALE']
# 10

# %% [markdown]
# On remarque que certaines informations ne nous intéressent pas dans ces données, on décide alors de les effacés. Ces informations peuvent être intéressantes mais il est difficile d'intégrer le volumme des échanges dans notre modèle prédictoire.

# %%
new_df = df.drop(columns = ["ticker", "volume"])
new_df
# Out:
#                  label        date       open       high        low  \
# 0                  ADP       43832    176.800    178.100    175.100
# 1                  ADP       43833    176.000    176.000    173.200
# 2                  ADP       43836    173.300    173.300    170.900
# 3                  ADP       43837    172.700    173.100    171.900
# 4                  ADP       43838    171.800    173.600    171.300
# ...                ...         ...        ...        ...        ...
# 7340  NASDAQ Composite  11/11/2022  11124.749  11352.429  11069.829
# 7341  NASDAQ Composite  14/11/2022  11233.904  11350.125  11167.165
# 7342  NASDAQ Composite  15/11/2022  11474.820  11492.616  11241.152
# 7343  NASDAQ Composite  16/11/2022  11260.095  11286.101  11162.923
# 7344  NASDAQ Composite  17/11/2022  11008.672  11198.838  11006.213
#
#           close currency
# 0       176.100      EUR
# 1       173.700      EUR
# 2       171.700      EUR
# 3       172.100      EUR
# 4       173.600      EUR
# ...         ...      ...
# 7340  11323.331      NaN
# 7341  11196.220      NaN
# 7342  11358.410      NaN
# 7343  11183.659      NaN
# 7344  11144.958      NaN
#
# [7345 rows x 7 columns]

# %%
liste_df=[]

for i in range(len(lst)):
    df0=new_df[new_df.label==lst[i]]
    liste_df.append(df0)

# %%
liste_df
# Out:
# [    label   date    open    high     low   close currency
#  0     ADP  43832  176.80  178.10  175.10  176.10      EUR
#  1     ADP  43833  176.00  176.00  173.20  173.70      EUR
#  2     ADP  43836  173.30  173.30  170.90  171.70      EUR
#  3     ADP  43837  172.70  173.10  171.90  172.10      EUR
#  4     ADP  43838  171.80  173.60  171.30  173.60      EUR
#  ..    ...    ...     ...     ...     ...     ...      ...
#  737   ADP  44876  143.00  146.95  142.70  146.50      EUR
#  738   ADP  44879  146.25  149.20  146.25  147.55      EUR
#  739   ADP  44880  147.35  150.20  146.65  148.05      EUR
#  740   ADP  44881  147.85  148.20  140.90  141.80      EUR
#  741   ADP  44882  142.15  143.10  140.90  142.60      EUR
#
#  [742 rows x 7 columns],
#       label   date    open    high     low   close currency
#  2226   AXA  43832  25.390  25.585  25.315  25.460      EUR
#  2227   AXA  43833  25.380  25.525  25.215  25.470      EUR
#  2228   AXA  43836  25.200  25.255  24.905  25.135      EUR
#  2229   AXA  43837  25.240  25.350  25.200  25.290      EUR
#  2230   AXA  43838  25.140  25.375  25.100  25.280      EUR
#  ...    ...    ...     ...     ...     ...     ...      ...
#  2963   AXA  44876  26.565  26.935  26.445  26.590      EUR
#  2964   AXA  44879  26.735  26.965  26.670  26.700      EUR
#  2965   AXA  44880  26.820  26.830  26.335  26.630      EUR
#  2966   AXA  44881  26.600  26.950  26.560  26.695      EUR
#  2967   AXA  44882  26.825  26.855  26.250  26.630      EUR
#
#  [742 rows x 7 columns],
#              label   date   open   high    low  close currency
#  1484  BNP PARIBAS  43832  53.20  54.00  53.18  53.58      EUR
#  1485  BNP PARIBAS  43833  53.07  53.17  52.59  52.94      EUR
#  1486  BNP PARIBAS  43836  52.04  52.70  51.64  52.68      EUR
#  1487  BNP PARIBAS  43837  52.93  53.14  52.46  52.66      EUR
#  1488  BNP PARIBAS  43838  52.27  53.02  52.01  52.78      EUR
#  ...           ...    ...    ...    ...    ...    ...      ...
#  2221  BNP PARIBAS  44876  51.30  52.04  50.97  51.76      EUR
#  2222  BNP PARIBAS  44879  52.08  52.35  51.48  52.18      EUR
#  2223  BNP PARIBAS  44880  52.33  52.78  51.97  52.47      EUR
#  2224  BNP PARIBAS  44881  52.40  52.51  51.83  52.09      EUR
#  2225  BNP PARIBAS  44882  52.37  52.55  51.71  52.51      EUR
#
#  [742 rows x 7 columns],
#         label        date     open     high      low    close currency
#  4452  CAC 40  02/01/2020  6016.61  6062.92  6011.21  6041.50      NaN
#  4453  CAC 40  03/01/2020  6007.96  6044.16  5994.59  6044.16      NaN
#  4454  CAC 40  06/01/2020  6001.21  6017.97  5955.25  6013.59      NaN
#  4455  CAC 40  07/01/2020  6033.22  6065.74  6000.00  6012.35      NaN
# On doit aussi changer les dates pour les autres tableaux

# %%
#on modifie d'abord les devises des actions

liste_df[3]=liste_df[3].fillna("EUR")
liste_df[5]=liste_df[5].fillna("EUR")
liste_df[6]=liste_df[6].fillna("USD")
liste_df[7]=liste_df[7].fillna("USD")
liste_df
# Out:
# [    label   date    open    high     low   close currency
#  0     ADP  43832  176.80  178.10  175.10  176.10      EUR
#  1     ADP  43833  176.00  176.00  173.20  173.70      EUR
#  2     ADP  43836  173.30  173.30  170.90  171.70      EUR
#  3     ADP  43837  172.70  173.10  171.90  172.10      EUR
#  4     ADP  43838  171.80  173.60  171.30  173.60      EUR
#  ..    ...    ...     ...     ...     ...     ...      ...
#  737   ADP  44876  143.00  146.95  142.70  146.50      EUR
#  738   ADP  44879  146.25  149.20  146.25  147.55      EUR
#  739   ADP  44880  147.35  150.20  146.65  148.05      EUR
#  740   ADP  44881  147.85  148.20  140.90  141.80      EUR
#  741   ADP  44882  142.15  143.10  140.90  142.60      EUR
#
#  [742 rows x 7 columns],
#       label   date    open    high     low   close currency
#  2226   AXA  43832  25.390  25.585  25.315  25.460      EUR
#  2227   AXA  43833  25.380  25.525  25.215  25.470      EUR
#  2228   AXA  43836  25.200  25.255  24.905  25.135      EUR
#  2229   AXA  43837  25.240  25.350  25.200  25.290      EUR
#  2230   AXA  43838  25.140  25.375  25.100  25.280      EUR
#  ...    ...    ...     ...     ...     ...     ...      ...
#  2963   AXA  44876  26.565  26.935  26.445  26.590      EUR
#  2964   AXA  44879  26.735  26.965  26.670  26.700      EUR
#  2965   AXA  44880  26.820  26.830  26.335  26.630      EUR
#  2966   AXA  44881  26.600  26.950  26.560  26.695      EUR
#  2967   AXA  44882  26.825  26.855  26.250  26.630      EUR
#
#  [742 rows x 7 columns],
#              label   date   open   high    low  close currency
#  1484  BNP PARIBAS  43832  53.20  54.00  53.18  53.58      EUR
#  1485  BNP PARIBAS  43833  53.07  53.17  52.59  52.94      EUR
#  1486  BNP PARIBAS  43836  52.04  52.70  51.64  52.68      EUR
#  1487  BNP PARIBAS  43837  52.93  53.14  52.46  52.66      EUR
#  1488  BNP PARIBAS  43838  52.27  53.02  52.01  52.78      EUR
#  ...           ...    ...    ...    ...    ...    ...      ...
#  2221  BNP PARIBAS  44876  51.30  52.04  50.97  51.76      EUR
#  2222  BNP PARIBAS  44879  52.08  52.35  51.48  52.18      EUR
#  2223  BNP PARIBAS  44880  52.33  52.78  51.97  52.47      EUR
#  2224  BNP PARIBAS  44881  52.40  52.51  51.83  52.09      EUR
#  2225  BNP PARIBAS  44882  52.37  52.55  51.71  52.51      EUR
#
#  [742 rows x 7 columns],
#         label        date     open     high      low    close currency
#  4452  CAC 40  02/01/2020  6016.61  6062.92  6011.21  6041.50      EUR
#  4453  CAC 40  03/01/2020  6007.96  6044.16  5994.59  6044.16      EUR
#  4454  CAC 40  06/01/2020  6001.21  6017.97  5955.25  6013.59      EUR
#  4455  CAC 40  07/01/2020  6033.22  6065.74  6000.00  6012.35      EUR
#  4456  CAC 40  08/01/2020  5986.81  6031.00  5972.77  6031.00      EUR
for i in range(5,5+len(liste_action_USA)):
    liste_df[i].open = liste_df[i].open*0.95
    liste_df[i].high = liste_df[i].high*0.95
    liste_df[i].low = liste_df[i].low*0.95
    liste_df[i].close = liste_df[i].close*0.95
    liste_df[i] = liste_df[i].replace("USD", "EUR")
liste_df[6]
# Out:
#                  label        date         open         high          low  \
# 6619  NASDAQ Composite  02/01/2020   8587.48605   8638.75660   8560.34550
# 6620  NASDAQ Composite  03/01/2020   8527.61040   8612.46820   8527.61040
# 6621  NASDAQ Composite  06/01/2020   8496.32690   8618.78760   8496.32690
# 6622  NASDAQ Composite  07/01/2020   8622.81275   8637.33255   8590.42535
# 6623  NASDAQ Composite  08/01/2020   8614.62660   8710.44265   8606.41290
# ...                ...         ...          ...          ...          ...
# 7340  NASDAQ Composite  11/11/2022  10568.51155  10784.80755  10516.33755
# 7341  NASDAQ Composite  14/11/2022  10672.20880  10782.61875  10608.80675
# 7342  NASDAQ Composite  15/11/2022  10901.07900  10917.98520  10679.09440
# 7343  NASDAQ Composite  16/11/2022  10697.09025  10721.79595  10604.77685
# 7344  NASDAQ Composite  17/11/2022  10458.23840  10638.89610  10455.90235
#
#             close currency
# 6619   8637.57955      EUR
# 6620   8569.73150      EUR
# 6621   8617.89175      EUR
# 6622   8615.15195      EUR
# 6623   8672.77990      EUR
# ...           ...      ...
# 7340  10757.16445      EUR
# 7341  10636.40900      EUR
# 7342  10790.48950      EUR
# 7343  10624.47605      EUR
# 7344  10587.71010      EUR
#
# [726 rows x 7 columns]

# %%
#on modifie les dates

# %% [markdown]
# On fait désormais des graphiques des courbes des prix des différentes actions.

# %%
len(liste_action_USA)
# Out:
# 2

# %% [markdown]
# On effectue désormais une visualisation des données.
# Pour cela, on décide donc de faire des graphiques des prix de chaque actions sur leurs prix d'ouverture.

# %%
liste_df[0]['open']
# Out:
# 0      176.80
# 1      176.00
# 2      173.30
# 3      172.70
# 4      171.80
#         ...
# 737    143.00
# 738    146.25
# 739    147.35
# 740    147.85
# 741    142.15
# Name: open, Length: 742, dtype: float64

# %%
for i in range(len(liste_df)):
    j=i+1
    new_df = liste_df[i]['open']
    plt.subplot(len(liste_df),1,j)
    plt.plot(new_df) 
    plt.title("Evolution des prix des actions de " + lst[i])
    plt.ylabel("Valeurs")
    plt.xlabel("Temps")
             
             
             
#new_df.plot(x="Temps", y = "Valeurs", title = "Evolution du prix des actions" + lst[i])

# %% [markdown]
# Il faudra modifier l'affichage de l'évolution des prix, car il est très condensé. Ce qui rend illisible n'importe qu'elle analyse de l'évolution des prix.
# Il faut aussi voir si ce que nous pouvons visualiser aussi ?

# %% [markdown]
# III La modélisation, une manière prédictive pour connaître les prix ?

# %% [markdown]
# Dans cette partie on va donc s'inspirer de la régression linéaire sur une action, et la généralisé sur le tout.
# On décide alors de passer par une boucle for

# %%
for i in range(len(liste_df)):
    X1 = liste_df[i]['open']
    X1 = X1.to_numpy()
    X = np.delete(X1, [-1])
    Y = np.delete(X1, [0])
    
    #On définit les tests, pour cela il nous faut une valeur ou arreter les données on la note p
    p = int((2/3)*len(X))
    X_train = X[:p]
    Y_train = Y[:p]
